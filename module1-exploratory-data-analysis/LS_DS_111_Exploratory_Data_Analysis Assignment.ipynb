# %% [markdown]
# #Learning Objectives
#
# # Exploratory Data Analysis
#
# - Objective 01 - submit assignments and save work via GitHub
# - Objective 02 - load a CSV dataset from a URL using `pandas.read_csv`
# - Objective 03 - load a CSV dataset from a local file using `pandas.read_csv
# - Objective 04 - use basic Pandas functions for Exploratory Data Analysis-EDA
# - Objective 05 - describe and discriminate between basic data types such as categorical, quantitative, continuous, discrete, ordinal, nominal and identifier

# %% [markdown]
# #Explore the University of California - Irvine Adult Dataset

# %% [markdown]
# ###1) Load a dataset via its URL.
#
# Load the Adult dataset from: 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
#
# Specify the column headers as:'age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week','native-country', 'income']

# %%
#Code here
import pandas as pd

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
header = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week','native-country', 'income']
df = pd.read_csv(url, names = header)
df
# Out:
#        age          workclass  fnlwgt  ... hours-per-week  native-country  income
# 0       39          State-gov   77516  ...             40   United-States   <=50K
# 1       50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2       38            Private  215646  ...             40   United-States   <=50K
# 3       53            Private  234721  ...             40   United-States   <=50K
# 4       28            Private  338409  ...             40            Cuba   <=50K
# ...    ...                ...     ...  ...            ...             ...     ...
# 32556   27            Private  257302  ...             38   United-States   <=50K
# 32557   40            Private  154374  ...             40   United-States    >50K
# 32558   58            Private  151910  ...             40   United-States   <=50K
# 32559   22            Private  201490  ...             20   United-States   <=50K
# 32560   52       Self-emp-inc  287927  ...             40   United-States    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ###2) Print the first 5 and the last 5 rows.

# %%
#Code here
df.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week  native-country  income
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
#Code here
df.tail()
# Out:
#        age      workclass  fnlwgt  ... hours-per-week  native-country  income
# 32556   27        Private  257302  ...             38   United-States   <=50K
# 32557   40        Private  154374  ...             40   United-States    >50K
# 32558   58        Private  151910  ...             40   United-States   <=50K
# 32559   22        Private  201490  ...             20   United-States   <=50K
# 32560   52   Self-emp-inc  287927  ...             40   United-States    >50K
#
# [5 rows x 15 columns]

# %% [markdown]
# ###3) Determine the data type of each varaible.

# %%
#Code here
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %% [markdown]
# ###4) Determine the dimensions of the dataset.

# %%
#Code here
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# ###5) Are there any missing values in the dataset?
# Check for missing values using .isnull().sum().

# %%
#Code here
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# ###6) Use the .describe() function in order to see the summary statistics of the numeric columns.
#
# Are there any values shown that might be a code for missing data?  We'll learn how to change the values in a DataFrame tomorrow.

# %%
#Code here
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Answer question here.

# %% [markdown]
# ###7) Use the .describe(exclude='number') function to calculate summary statistics for the non-numeric columns

# %%
#Code here
df.describe(exclude='category')
# Out:
#              serRace          year  ...    carMake     driver
# count   34884.000000  34884.000000  ...      34884      34884
# unique           NaN           NaN  ...         10        683
# top              NaN           NaN  ...  Chevrolet  RickyRudd
# freq             NaN           NaN  ...      12663        803
# mean      468.597151   1990.027950  ...        NaN        NaN
# std       259.245275      8.523917  ...        NaN        NaN
# min         1.000000   1975.000000  ...        NaN        NaN
# 25%       247.000000   1983.000000  ...        NaN        NaN
# 50%       478.000000   1991.000000  ...        NaN        NaN
# 75%       696.000000   1998.000000  ...        NaN        NaN
# max       898.000000   2003.000000  ...        NaN        NaN
#
# [11 rows x 10 columns]

# %%
df.describe()
# Out:
#             serRace          year  ...         prize      carsRace
# count  34884.000000  34884.000000  ...  3.488400e+04  34884.000000
# mean     468.597151   1990.027950  ...  2.704011e+04     39.406146
# std      259.245275      8.523917  ...  4.455498e+04      4.348333
# min        1.000000   1975.000000  ...  0.000000e+00     22.000000
# 25%      247.000000   1983.000000  ...  3.835000e+03     37.000000
# 50%      478.000000   1991.000000  ...  1.201000e+04     41.000000
# 75%      696.000000   1998.000000  ...  3.649625e+04     43.000000
# max      898.000000   2003.000000  ...  2.277975e+06     50.000000
#
# [8 rows x 8 columns]

# %%
df
# Out:
#        serRace  year  yearRace  ...  carsRace    carMake          driver
# 0            1  1975         1  ...        35    Matador    BobbyAllison
# 1            1  1975         1  ...        35    Mercury    DavidPearson
# 2            1  1975         1  ...        35  Chevrolet     CecilGordon
# 3            1  1975         1  ...        35      Dodge      DaveMarcis
# 4            1  1975         1  ...        35       Ford     ElmoLangley
# ...        ...   ...       ...  ...       ...        ...             ...
# 34879      898  2003        36  ...        43  Chevrolet     MikeSkinner
# 34880      898  2003        36  ...        43      Dodge       JeffGreen
# 34881      898  2003        36  ...        43  Chevrolet  MichaelWaltrip
# 34882      898  2003        36  ...        43  Chevrolet    JohnAndretti
# 34883      898  2003        36  ...        43       Ford     MattKenseth
#
# [34884 rows x 10 columns]

# %%
# alternatively to the solution above I prefer to use:-
import numpy as np
df.describe(exclude=np.number)
# Out:
#        workclass education       marital-status  ...    sex  native-country  income
# count      32561     32561                32561  ...  32561           32561   32561
# unique         9        16                    7  ...      2              42       2
# top      Private   HS-grad   Married-civ-spouse  ...   Male   United-States   <=50K
# freq       22696     10501                14976  ...  21790           29170   24720
#
# [4 rows x 9 columns]

# %% [markdown]
# ###8) Calculate the number of observations in each category of the relationship variable.

# %%
#Code here
df.relationship.value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64

# %% [markdown]
# ###9) Select and print the occupation category.

# %%
#Code here
df.occupation # can also use df['occupation']
# Out:
# 0              Adm-clerical
# 1           Exec-managerial
# 2         Handlers-cleaners
# 3         Handlers-cleaners
# 4            Prof-specialty
#                 ...
# 32556          Tech-support
# 32557     Machine-op-inspct
# 32558          Adm-clerical
# 32559          Adm-clerical
# 32560       Exec-managerial
# Name: occupation, Length: 32561, dtype: object

# %% [markdown]
# #Load a dataset saved on your personal computer
#
# Go to the website http://users.stat.ufl.edu/~winner/datasets.html and scroll down to **NASCAR Race Results by Driver 1975-2003**
#
# Download and save the .csv file to your personal computer.

# %% [markdown]
# ###10) Upload the dataset using the following commands.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0631ec8e-a3d4-49aa-a893-3ab4cde60d8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0631ec8e-a3d4-49aa-a893-3ab4cde60d8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nascard.csv to nascard (1).csv

# %%
import io # importing here so that I can get io methods recommendation from colab below
uploaded
# Out:
# {'nascard.csv': b"serRace,year,yearRace,finish,start,laps,prize,carsRace,carMake,driver\r\n1,1975,1,1,1,191,12035,35,Matador,BobbyAllison\r\n1,1975,1,2,2,191,8135,35,Mercury,DavidPearson\r\n1,1975,1,3,25,184,6535,35,Chevrolet,CecilGordon\r\n1,1975,1,4,27,183,5035,35,Dodge,DaveMarcis\r\n1,1975,1,5,22,178,3835,35,Ford,ElmoLangley\r\n1,1975,1,6,35,175,2885,35,Chevrolet,JamesHylton\r\n1,1975,1,7,3,172,3185,35,Dodge,RichardPetty\r\n1,1975,1,8,21,168,2485,35,Chevrolet,GaryMatthews\r\n1,1975,1,9,33,167,2335,35,Dodge,EdNegre\r\n1,1975,1,10,10,166,2185,35,Chevrolet,HershelMcGriff\r\n1,1975,1,11,17,166,1985,35,Chevrolet,RichardChildress\r\n1,1975,1,12,24,148,1835,35,Chevrolet,DonPuskarich\r\n1,1975,1,13,6,145,2235,35,Dodge,RayElder\r\n1,1975,1,14,28,142,1635,35,Chevrolet,J.D.McDuffie\r\n1,1975,1,15,18,135,1535,35,Chevrolet,LarryEsau\r\n1,1975,1,16,11,125,1435,35,Ford,BillOsborne\r\n1,1975,1,17,15,125,1385,35,Chevrolet,ChuckWahl\r\n1,1975,1,18,29,118,1335,35,Chevrolet,BillSchmitt\r\n1,1975,1,19,16,117,1285,35,Chevrolet,RichardWhite\r\n1,1975,1,20,32,110,1230,35,Chevrolet,DonReynolds\r\n1,1975,1,21,26,97,1150,35,Ford,SonnyEasley\r\n1,1975,1,22,30,96,1125,35,Chevrolet,RonEsau\r\n1,1975,1,23,13,65,1100,35,Chevrolet,HughPearson\r\n1,1975,1,24,4,44,1075,35,Chevrolet,BennyParsons\r\n1,1975,1,25,12,44,1025,35,Chevrolet,GlenFrancis\r\n1,1975,1,26,34,40,975,35,Ford,PeteTorres\r\n1,1975,1,27,5,36,925,35,Dodge,ChuckBown\r\n1,1975,1,28,19,35,875,35,Ford,ChuckLittle\r\n1,1975,1,29,31,28,825,35,Ford,G.t.Tallas\r\n1,1975,1,30,7,17,775,35,Chevrolet,DickBown\r\n1,1975,1,31,23,15,720,35,Chevrolet,WalterBallard\r\n1,1975,1,32,8,14,670,35,Ford,HarryJefferson\r\n1,1975,1,33,9,13,620,35,Chevrolet,JimmyInsolo\r\n1,1975,1,34,20,5,570,35,Ford,CarlAdams\r\n1,1975,1,35,14,4,520,35,Dodge,IvanBaldwin\r\n2,1975,2,1,32,200,40900,40,Chevrolet,BennyParsons\r\n2,1975,2,2,3,199,25100,40,Matador,BobbyAllison\r\n2,1975,2,3,6,198,17900,40,Chevrolet,CaleYarborough\r\n2,1975,2,4,2,198,13450,40,Mercury,DavidPearson\r\n2,1975,2,5,31,197,11350,40,Chevrolet,RamoStott\r\n2,1975,2,6,8,197,10000,40,Dodge,DaveMarcis\r\n2,1975,2,7,4,192,9100,40,Dodge,RichardPetty\r\n2,1975,2,8,10,191,7850,40,Chevrolet,RichiePanch\r\n2,1975,2,9,37,191,7150,40,Dodge,G.C.Spencer\r\n2,1975,2,10,17,189,6450,40,Chevrolet,JamesHylton\r\n2,1975,2,11,9,188,5250,40,Chevrolet,AJFoyt\r\n2,1975,2,12,39,185,4600,40,Chevrolet,BruceJacobi\r\n2,1975,2,13,30,184,3950,40,Ford,BobBurcham\r\n2,1975,2,14,26,184,3500,40,Dodge,EdNegre\r\n2,1975,2,15,15,183,3250,40,Chevrolet,CecilGordon\r\n2,1975,2,16,16,176,2800,40,Dodge,FerrelHarris\r\n2,1975,2,17,35,162,2600,40,Chevrolet,CooCooMarlin\r\n2,1975,2,18,36,150,2400,40,Chevrolet,RichardChildress\r\n2,1975,2,19,7,146,2200,40,Chevrolet,LenniePond\r\n2,1975,2,20,13,144,2050,40,Ford,BuddyBaker\r\n2,1975,2,21,12,118,1875,40,Chevrolet,DaveSisco\r\n2,1975,2,22,5,104,1800,40,Ford,DickBrooks\r\n2,1975,2,23,24,83,1725,40,Ford,TommyGale\r\n2,1975,2,24,40,67,1650,40,Chevrolet,GeorgeFollmer\r\n2,1975,2,25,22,67,1575,40,Chevrolet,WalterBallard\r\n2,1975,2,26,33,54,1500,40,Chevrolet,DarrellWaltrip\r\n2,1975,2,27,11,51,1475,40,Chevrolet,JohnnyRutherford\r\n2,1975,2,28,1,36,1450,40,Chevrolet,DonnieAllison\r\n2,1975,2,29,18,30,1425,40,Chevrolet,RandyTissot\r\n2,1975,2,30,38,13,1400,40,Chevrolet,HershelMcGriff\r\n2,1975,2,31,21,7,1350,40,Ford,RickNewsom\r\n2,1975,2,32,20,4,1325,40,Chevrolet,BruceHill\r\n2,1975,2,33,14,3,1300,40,Chevrolet,J.D.McDuffie\r\n2,1975,2,34,19,3,1275,40,Chevrolet,JoeMihalic\r\n2,1975,2,35,34,3,1250,40,Dodge,JimVandiver\r\n2,1975,2,36,27,3,1225,40,Mercury,DickTrickle\r\n2,1975,2,37,25,3,1175,40,Chevrolet,GrantAdcox\r\n2,1975,2,38,23,3,1150,40,Ford,DanDaughty\r\n2,1975,2,39,28,3,1125,40,Dodge,MartyRobbins\r\n2,1975,2,40,29,3,1100,40,Ford,WarrenTo0/0\r\n3,1975,3,1,1,500,6265,22,Dodge,RichardPetty\r\n3,1975,3,2,3,494,4160,22,Chevrolet,LenniePond\r\n3,1975,3,3,2,491,2935,22,Chevrolet,BennyParsons\r\n3,1975,3,4,5,489,1760,22,Ford,DickBrooks\r\n3,1975,3,5,9,476,1385,22,Ford,ElmoLa ...

# %%
#Code here

df = pd.read_csv(io.BytesIO(uploaded['nascard.csv']))
df
# Out:
#        serRace  year  yearRace  ...  carsRace    carMake          driver
# 0            1  1975         1  ...        35    Matador    BobbyAllison
# 1            1  1975         1  ...        35    Mercury    DavidPearson
# 2            1  1975         1  ...        35  Chevrolet     CecilGordon
# 3            1  1975         1  ...        35      Dodge      DaveMarcis
# 4            1  1975         1  ...        35       Ford     ElmoLangley
# ...        ...   ...       ...  ...       ...        ...             ...
# 34879      898  2003        36  ...        43  Chevrolet     MikeSkinner
# 34880      898  2003        36  ...        43      Dodge       JeffGreen
# 34881      898  2003        36  ...        43  Chevrolet  MichaelWaltrip
# 34882      898  2003        36  ...        43  Chevrolet    JohnAndretti
# 34883      898  2003        36  ...        43       Ford     MattKenseth
#
# [34884 rows x 10 columns]

# %% [markdown]
# ###11) Print the first 10 rows of the dataset

# %%
#Code here
df.head(10)
# Out:
#    serRace  year  yearRace  finish  ...  prize  carsRace    carMake          driver
# 0        1  1975         1       1  ...  12035        35    Matador    BobbyAllison
# 1        1  1975         1       2  ...   8135        35    Mercury    DavidPearson
# 2        1  1975         1       3  ...   6535        35  Chevrolet     CecilGordon
# 3        1  1975         1       4  ...   5035        35      Dodge      DaveMarcis
# 4        1  1975         1       5  ...   3835        35       Ford     ElmoLangley
# 5        1  1975         1       6  ...   2885        35  Chevrolet     JamesHylton
# 6        1  1975         1       7  ...   3185        35      Dodge    RichardPetty
# 7        1  1975         1       8  ...   2485        35  Chevrolet    GaryMatthews
# 8        1  1975         1       9  ...   2335        35      Dodge         EdNegre
# 9        1  1975         1      10  ...   2185        35  Chevrolet  HershelMcGriff
#
# [10 rows x 10 columns]

# %% [markdown]
# ###12) Answer the following questions for the variables prize, carMake and driver:
#
#
# *   Is the variable categorical or quantitative?
# *   If the variable is categorical, determine if it is ordinal, nominal or an identifier variable.
# *   If the vriable is quantitative, determine if it is continuous or discrite.

# %% [markdown]
# #Answer here.

# %% [markdown]
# **Answers follow below:-**
#
# Used the data description from the data source to answer
#
# 1) Prize is quantitative while carMake and driver is categorical.
#
# 2) carMake is nominal i.e. the data does not have any natural order to it and driver is an identified variable i.e. mere identifier variable to distinguish a driver from another.
#
# 3) Prize is continous as it can be counted with precision. For example, $ 12035 and 52 cents. Although, the data only captures the dollar figures as a whole number.

# %% [markdown]
# #Data Storytelling Project Milestone
#
# Begin looking at Data Storytelling (previously called Build Week) [project info](https://github.com/LambdaSchool/DS-Unit-1-Build) and at projects created by previous Lambda students.
#
# [Projects — Lambda DS1!](https://drive.google.com/file/d/1RJoAqDgawzSHOJPlDQRRlfz-EnIsskpL/view)
